# %% [markdown]
# # Find best models
#
# This notebook will load all models and re-evaluate them on all 5 folds, without re-fit. The best model for each phenotype will be selected for further experiments

# %%
from _load_llm_results import *

import numpy as np
import warnings
import os
import importlib
import sys; sys.path.append('../')
from evaluate_model import read_data
from sklearn.metrics import average_precision_score, roc_auc_score

warnings.filterwarnings("ignore")

# %matplotlib inline

from tqdm import tqdm
from glob import glob

def evaluate_all_folds(metric, cp_function, cp_df, folds=['A', 'B', 'C', 'D', 'E'], bootstrap=False, n_reps=1_000, override_runid=False):
    
    runid = cp_df['RunID']
    if override_runid:
        runid = '101' # enforcing to use the held out dataset
        # print("Overriding RunID, Using runID", runid)
        cp_df['RunID'] = runid
    
    def eval(X, y):
        try:
            prob = np.array(cp_function(X))
        except Exception:
            prob = np.zeros(shape=len(X))
        try:
            if metric in [average_precision_score, roc_auc_score]:
                return metric(y, prob)
            else:
                return metric(y, np.where(prob> 0.5), 1, 0)
        except ValueError:
            return np.nan

    for FOLD in folds:
        X_train, y_train, X_test, y_test = read_data(
            targets_rev[cp_df['target']], FOLD, runid, cp_df['scale'],
            cp_df['icd_only'], data_dir, cp_df['random_state']
        )

        entry = f"{metric.__name__}_fold_out_{FOLD}"
        if bootstrap:
            val_samples = []
            for i in tqdm(range(n_reps)):
                samples = np.random.randint(0,len(y_test)-1, size=len(y_test))
                val_samples.append( eval(X_test.iloc[samples, :], y_test.iloc[samples]) )

            cp_df[f"{entry}_mean"] = np.mean(val_samples)
            cp_df[f"{entry}_std"] = np.std(val_samples)
            cp_df[f"{entry}_ci_upper"] = np.quantile(val_samples,0.95)
            cp_df[f"{entry}_ci_lower"] = np.quantile(val_samples,0.05)
        else:
            cp_df[entry] = eval(X_test, y_test)

    return cp_df

def load_results(constraints=dict(scale=[False])):
    count = 0
    for file in tqdm(glob(f"{results_path}/**/*.json", recursive=True)):
        
        try:
            cp_df = pd.read_json(file, typ="series")
        except Exception as e:
            # print("Bad results in file", file)
            continue
            
        # unifying column name
        cp_df = cp_df.rename(index={"few_feature": "icd_only"})
            
        stay = True
        for kc, vc in constraints.items():
            if cp_df[kc] not in vc:
                stay = False
                # print("skipping", file)
                break
        if not stay:
            # print('continuing')
            continue

        # Evaluating the program in the other folds
        cp_file = file.replace('.json', '_program') \
                      .replace(cp_df['target'], targets_rev[cp_df['target']]) \
                      .replace('/', '.')[3:]

        if 'iterative' not in file: # removing the fold from file name if not iterative
            cp_file = cp_file.replace(f"_{cp_df['fold']}_", '__')

        # print(cp_file)

        try:
            cp_module = importlib.__import__(
                cp_file,
                globals(),
                locals(),
                ["predict_hyptertension"],
            )
            cp_function = cp_module.predict_hypertension

            # Evaluating on other held-out folds. notice that the LLMs did not see the
            # entire training data even during its training!
            cp_df = evaluate_all_folds(average_precision_score, cp_function, cp_df)
        except:
            continue

        results.append(cp_df)
        count += 1

    print('loaded',count,'files')
    results_df = pd.DataFrame(data=results)\

    # Beautifying it
    results_df["model"] = results_df["model"].apply(lambda m: nice_model_labels[m])
    results_df["target"] = results_df["target"].apply(lambda t: dnames_to_nice[t])

    results_df = results_df[results_df["model"].isin(order)]

    print(results_df["model"].unique())
    print(results_df["target"].unique())
    
    return results_df
    
results_df = pd.concat([
    load_results( # rich prompt, expert features
        constraints = {
            'scale': [False],
            'model': ['GPT_4o_iterative_Classifier'], 
            'prompt_richness' : [True],
            'icd_only' : [True],
        }
    ),
    load_results( # simple prompt, all features
        constraints = {
            'scale': [False],
            'model': ['GPT_4o_iterative_Classifier'], 
            'prompt_richness' : [False],
            'icd_only' : [False],
        }
    )
])

# Making it the format seaborn likes
results_df_melted = pd.melt(
    results_df, 
    id_vars=['model', 'target', 'fold', 'RunID', 'random_state', 'prompt_richness', 'icd_only', 'scale']
)

print(results_df.columns)
print(results_df.shape)
# Out:
# 100%|██████████| 7200/7200 [02:05<00:00, 57.18it/s]
# loaded 300 files
# ['gpt-4o-iter']
# ['HTN Heuristic' 'HTN Diagnosis' 'HTN-Hypokalemia Diagnosis'
#  'Htn-Hypokalemia Heuristic' 'Resistant HTN Heuristic'
#  'Resistant HTN Diagnosis']
# 100%|██████████| 7200/7200 [11:24<00:00, 10.51it/s]
# loaded 300 files
# ['gpt-4o-iter']
# ['HTN Heuristic' 'HTN Diagnosis' 'HTN-Hypokalemia Diagnosis'
#  'Htn-Hypokalemia Heuristic' 'Resistant HTN Heuristic'
#  'Resistant HTN Diagnosis']
# Index(['accuracy_score_train', 'precision_score_train',
#        'average_precision_score_train', 'roc_auc_score_train',
#        'balanced_accuracy_score_train', 'accuracy_score_test',
#        'precision_score_test', 'average_precision_score_test',
#        'roc_auc_score_test', 'balanced_accuracy_score_test', 'messages',
#        'model', 'target', 'fold', 'RunID', 'random_state', 'representation',
#        'representation_fmt', 'size', 'complexity', 'scale', 'icd_only',
#        'prompt_richness', 'time', 'pred', 'pred_proba',
#        'average_precision_score_fold_out_A',
#        'average_precision_score_fold_out_B',
#        'average_precision_score_fold_out_C',
#        'average_precision_score_fold_out_D',
#        'average_precision_score_fold_out_E'],
#       dtype='object')
# (900, 31)

# %%
print(results_df_melted.variable.unique())
display(results_df_melted.sample(5))
# Out:
# ['accuracy_score_train' 'precision_score_train'
#  'average_precision_score_train' 'roc_auc_score_train'
#  'balanced_accuracy_score_train' 'accuracy_score_test'
#  'precision_score_test' 'average_precision_score_test'
#  'roc_auc_score_test' 'balanced_accuracy_score_test' 'messages'
#  'representation' 'representation_fmt' 'size' 'complexity' 'time' 'pred'
#  'pred_proba' 'average_precision_score_fold_out_A'
#  'average_precision_score_fold_out_B' 'average_precision_score_fold_out_C'
#  'average_precision_score_fold_out_D' 'average_precision_score_fold_out_E']
#              model                     target fold  RunID  random_state  \
# 13952  gpt-4o-iter  Htn-Hypokalemia Heuristic    A      1         16695
# 16068  gpt-4o-iter  Htn-Hypokalemia Heuristic    B      1          6933
# 11413  gpt-4o-iter              HTN Heuristic    B      1         24284
# 75     gpt-4o-iter              HTN Diagnosis    C      1         27690
# 12340  gpt-4o-iter              HTN Heuristic    E      1          1318
#
#        prompt_richness  icd_only  scale              variable  \
# 13952             True      True  False                  time
# 16068            False     False  False            pred_proba
# 11413            False     False  False    representation_fmt
# 75                True      True  False  accuracy_score_train
# 12340            False     False  False                  size
#
#                                                    value
# 13952                                          25.391346
# 16068  [0.999562938725658, 0.999999999991491, 0.99984...
# 11413  \nimport numpy as np\nimport pandas as pd\n\nd...
# 75                                              0.766342
# 12340                                                102

# %%
for prompt_richness in [True,False]:
    for icd_only in [True,False]:
        for metric in [
            'average_precision_score_fold_out', 
        ]:
            data = (
                results_df_melted[ ( (results_df_melted['variable'].str.contains(metric))
                                   | (results_df_melted['variable']=='size') )
                                 & (results_df_melted['prompt_richness']==prompt_richness)
                                 & (results_df_melted['icd_only']==icd_only)
                ]
                .dropna()
            )

            if len(data)==0:
                continue

            print("prompt_richness", prompt_richness, "expert_features", icd_only)
                        
            # removing the fold name from the metric
            data['variable'].replace({f'{metric}{fold}' : metric for fold in ['_A', '_B', '_C', '_D', '_E']}, inplace=True)
            data['value'] = data['value'].astype(float)
            data['Strategy'] = ['SEDI / Train' if 'iter' in v or 'gpt' not in v else 'Zero Shot' for v in data['model'].values]

            # first we group each model's performance on the held out data and take the mean.
            # then, we ignore folds and random states to get the final model.
            model_metrics_all_folds = data.groupby([
                'target', 'model', 'prompt_richness', 'icd_only', 'Strategy', 'scale',
                'RunID', 'fold', 'random_state', 'variable']
            )['value'].mean().reset_index()

            model_metrics_all_folds = model_metrics_all_folds.pivot_table(
                index=['target', 'model', 'prompt_richness', 'icd_only', 'Strategy', 'scale',
                       'RunID', 'fold', 'random_state'],
                columns='variable',
                values='value'
            ).reset_index()

            # Sorting by size, in case of ties in metric
            best_models = model_metrics_all_folds\
                .sort_values([metric, 'size'], ascending=[False, True])\
                .drop_duplicates(['target', 'model', 'prompt_richness', 'icd_only', 'Strategy', 'scale'])
                
            display(best_models.T)

            best_models[f'size'] = np.nan
            for metric_f in [average_precision_score, roc_auc_score]:
                best_models[f'mean_{metric_f.__name__}_fold_out_mean'] = np.nan
                best_models[f'mean_{metric_f.__name__}_fold_out_std'] = np.nan
                best_models[f'mean_{metric_f.__name__}_fold_out_ci_lower'] = np.nan
                best_models[f'mean_{metric_f.__name__}_fold_out_ci_upper'] = np.nan
            

            # Evaluating it on the held out test partition -----
            held_out_performances = []
            for i, row in best_models.iterrows():
                # print(row)
                # finding the correct file
                filename = (
                    "/".join([results_path,
                              targets_rev[dnames_to_ugly[row['target']]],
                              nice_to_ugly[row['model']] ])
                    + "/"
                    + "_".join(
                        [
                            dnames_to_ugly[row['target']],
                            nice_to_ugly[row['model']],
                            str(row['scale']),
                            str(row['icd_only']),
                            str(row['prompt_richness']),
                            str(row['RunID']),
                            row['fold'],
                            str(row['random_state']),
                        ]
                    )
                    + '.json'
                )
                # print(filename)
                cp_df = pd.read_json(filename, typ="series")

                cp_df = cp_df.rename(index={"few_feature": "icd_only"})

                # Evaluating the program in the other folds
                cp_file = filename.replace('.json', '_program') \
                            .replace(cp_df['target'], targets_rev[cp_df['target']]) \
                            .replace('/', '.')[3:]

                if 'iterative' not in filename: # removing the fold from file name if not iterative
                    cp_file = cp_file.replace(f"_{cp_df['fold']}_", '__')

                # print(cp_file)

                cp_function = None
                try:
                    cp_module = importlib.__import__(
                        cp_file, # This is going to be unique for each algorithm
                        globals(),
                        locals(),
                        ["predict_hyptertension"],
                    )
                    cp_function = cp_module.predict_hypertension
                except:
                    continue
                
                cp_df['RunID'] = '101'
                best_models.loc[i, f'size'] = cp_df['size']
                for metric_f in [average_precision_score, roc_auc_score]:
                    cp_df = evaluate_all_folds(metric_f, cp_function, cp_df, ['A'], bootstrap=True, override_runid=True)
                    
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_mean'] = cp_df[f'{metric_f.__name__}_fold_out_A_mean']
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_std'] = cp_df[f'{metric_f.__name__}_fold_out_A_std']
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_ci_upper'] = cp_df[f'{metric_f.__name__}_fold_out_A_ci_upper']
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_ci_lower'] = cp_df[f'{metric_f.__name__}_fold_out_A_ci_lower']
                    
            display(best_models.T)
    
            print("-"*120)

            # Create LaTeX table
            latex_table = best_models.to_latex(
                index=True,
                column_format="lrrr",
                escape=False
            )
            
            # Save LaTeX table to file
            filename = f"{paper_dir}/tab_best_model_{metric}_{prompt_richness}_{icd_only}.tex"
            with open(filename, 'w') as f:
                f.write(latex_table)
            
            print(f"\nLaTeX table saved to {filename}\n")
# Out:
# prompt_richness True expert_features True
#                                                         151            75   \
# variable
# target                            Htn-Hypokalemia Heuristic  HTN Heuristic
# model                                           gpt-4o-iter    gpt-4o-iter
# prompt_richness                                        True           True
# icd_only                                               True           True
# Strategy                                       SEDI / Train   SEDI / Train
# scale                                                 False          False
# RunID                                                     1              1
# fold                                                      A              C
# random_state                                           6832          16695
# average_precision_score_fold_out                        1.0        0.97889
# size                                                   82.0          202.0
#
#                                             19                       284  \
# variable
# target                            HTN Diagnosis  Resistant HTN Heuristic
# model                               gpt-4o-iter              gpt-4o-iter
# prompt_richness                            True                     True
# icd_only                                   True                     True
# Strategy                           SEDI / Train             SEDI / Train
# scale                                     False                    False
# RunID                                         1                        1
# fold                                          B                        D
# random_state                              31658                    14724
# average_precision_score_fold_out       0.968017                 0.799027
# size                                      112.0                     70.0
#
#                                                         114  \
# variable
# target                            HTN-Hypokalemia Diagnosis
# model                                           gpt-4o-iter
# prompt_richness                                        True
# icd_only                                               True
# Strategy                                       SEDI / Train
# scale                                                 False
# RunID                                                     1
# fold                                                      B
# random_state                                          14724
# average_precision_score_fold_out                   0.740501
# size                                                  131.0
#
#                                                       226
# variable
# target                            Resistant HTN Diagnosis
# model                                         gpt-4o-iter
# prompt_richness                                      True
# icd_only                                             True
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    C
# random_state                                        24284
# average_precision_score_fold_out                 0.659152
# size                                                194.0
# 100%|██████████| 1000/1000 [00:02<00:00, 483.32it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 455.25it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 251.20it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 215.66it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 329.71it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 301.06it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 576.66it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 484.14it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 469.27it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 342.03it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 82.12it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 81.28it/s]
#                                                                       151  \
# variable
# target                                          Htn-Hypokalemia Heuristic
# model                                                         gpt-4o-iter
# prompt_richness                                                      True
# icd_only                                                             True
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    A
# random_state                                                         6832
# average_precision_score_fold_out                                      1.0
# size                                                                 82.0
# mean_average_precision_score_fold_out_mean                       0.978051
# mean_average_precision_score_fold_out_std                        0.012719
# mean_average_precision_score_fold_out_ci_lower                   0.955691
# mean_average_precision_score_fold_out_ci_upper                        1.0
# mean_roc_auc_score_fold_out_mean                                 0.983894
# mean_roc_auc_score_fold_out_std                                  0.009362
# mean_roc_auc_score_fold_out_ci_lower                             0.966292
# mean_roc_auc_score_fold_out_ci_upper                             0.995459
#
#                                                           75             19   \
# variable
# target                                          HTN Heuristic  HTN Diagnosis
# model                                             gpt-4o-iter    gpt-4o-iter
# prompt_richness                                          True           True
# icd_only                                                 True           True
# Strategy                                         SEDI / Train   SEDI / Train
# scale                                                   False          False
# RunID                                                       1              1
# fold                                                        C              B
# random_state                                            16695          31658
# average_precision_score_fold_out                      0.97889       0.968017
# size                                                    202.0          112.0
# mean_average_precision_score_fold_out_mean           0.981335       0.987772
# mean_average_precision_score_fold_out_std            0.006687       0.004505
# mean_average_precision_score_fold_out_ci_lower       0.969594       0.979897
# mean_average_precision_score_fold_out_ci_upper        0.99095        0.99442
# mean_roc_auc_score_fold_out_mean                     0.974089       0.979713
# mean_roc_auc_score_fold_out_std                      0.008328       0.006879
# mean_roc_auc_score_fold_out_ci_lower                  0.95901       0.968009
# mean_roc_auc_score_fold_out_ci_upper                 0.986796       0.990128
#
#                                                                     284  \
# variable
# target                                          Resistant HTN Heuristic
# model                                                       gpt-4o-iter
# prompt_richness                                                    True
# icd_only                                                           True
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  D
# random_state                                                      14724
# average_precision_score_fold_out                               0.799027
# size                                                               70.0
# mean_average_precision_score_fold_out_mean                     0.872852
# mean_average_precision_score_fold_out_std                      0.037872
# mean_average_precision_score_fold_out_ci_lower                 0.806401
# mean_average_precision_score_fold_out_ci_upper                 0.933441
# mean_roc_auc_score_fold_out_mean                               0.970483
# mean_roc_auc_score_fold_out_std                                 0.00879
# mean_roc_auc_score_fold_out_ci_lower                            0.95516
# mean_roc_auc_score_fold_out_ci_upper                            0.98375
#
#                                                                       114  \
# variable
# target                                          HTN-Hypokalemia Diagnosis
# model                                                         gpt-4o-iter
# prompt_richness                                                      True
# icd_only                                                             True
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    B
# random_state                                                        14724
# average_precision_score_fold_out                                 0.740501
# size                                                                131.0
# mean_average_precision_score_fold_out_mean                       0.835905
# mean_average_precision_score_fold_out_std                        0.042571
# mean_average_precision_score_fold_out_ci_lower                   0.763708
# mean_average_precision_score_fold_out_ci_upper                   0.905398
# mean_roc_auc_score_fold_out_mean                                 0.956503
# mean_roc_auc_score_fold_out_std                                  0.013181
# mean_roc_auc_score_fold_out_ci_lower                             0.933191
# mean_roc_auc_score_fold_out_ci_upper                             0.976108
#
#                                                                     226
# variable
# target                                          Resistant HTN Diagnosis
# model                                                       gpt-4o-iter
# prompt_richness                                                    True
# icd_only                                                           True
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  C
# random_state                                                      24284
# average_precision_score_fold_out                               0.659152
# size                                                              194.0
# mean_average_precision_score_fold_out_mean                     0.797437
# mean_average_precision_score_fold_out_std                      0.045401
# mean_average_precision_score_fold_out_ci_lower                  0.72363
# mean_average_precision_score_fold_out_ci_upper                 0.871333
# mean_roc_auc_score_fold_out_mean                               0.950868
# mean_roc_auc_score_fold_out_std                                0.012188
# mean_roc_auc_score_fold_out_ci_lower                           0.929059
# mean_roc_auc_score_fold_out_ci_upper                           0.969107
# ------------------------------------------------------------------------------------------------------------------------
#
# LaTeX table saved to ../paper_rebuttal/tab_best_model_average_precision_score_fold_out_True_True.tex
#
# prompt_richness False expert_features False
#                                             66             21   \
# variable
# target                            HTN Heuristic  HTN Diagnosis
# model                               gpt-4o-iter    gpt-4o-iter
# prompt_richness                           False          False
# icd_only                                  False          False
# Strategy                           SEDI / Train   SEDI / Train
# scale                                     False          False
# RunID                                         1              1
# fold                                          B              C
# random_state                              24284           6832
# average_precision_score_fold_out       0.994699       0.985126
# size                                      107.0          101.0
#
#                                                       295  \
# variable
# target                            Resistant HTN Heuristic
# model                                         gpt-4o-iter
# prompt_richness                                     False
# icd_only                                            False
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    E
# random_state                                        16695
# average_precision_score_fold_out                 0.828473
# size                                                157.0
#
#                                                         151  \
# variable
# target                            Htn-Hypokalemia Heuristic
# model                                           gpt-4o-iter
# prompt_richness                                       False
# icd_only                                              False
# Strategy                                       SEDI / Train
# scale                                                 False
# RunID                                                     1
# fold                                                      A
# random_state                                           6832
# average_precision_score_fold_out                   0.805917
# size                                                  193.0
#
#                                                       234  \
# variable
# target                            Resistant HTN Diagnosis
# model                                         gpt-4o-iter
# prompt_richness                                     False
# icd_only                                            False
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    D
# random_state                                        14724
# average_precision_score_fold_out                 0.688854
# size                                                153.0
#
#                                                         107
# variable
# target                            HTN-Hypokalemia Diagnosis
# model                                           gpt-4o-iter
# prompt_richness                                       False
# icd_only                                              False
# Strategy                                       SEDI / Train
# scale                                                 False
# RunID                                                     1
# fold                                                      A
# random_state                                          24481
# average_precision_score_fold_out                   0.621716
# size                                                  157.0
# 100%|██████████| 1000/1000 [00:02<00:00, 492.05it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 359.97it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 337.92it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 299.01it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 276.63it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 207.32it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 221.67it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 210.59it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 289.31it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 284.27it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 274.74it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 244.57it/s]
#                                                           66             21   \
# variable
# target                                          HTN Heuristic  HTN Diagnosis
# model                                             gpt-4o-iter    gpt-4o-iter
# prompt_richness                                         False          False
# icd_only                                                False          False
# Strategy                                         SEDI / Train   SEDI / Train
# scale                                                   False          False
# RunID                                                       1              1
# fold                                                        B              C
# random_state                                            24284           6832
# average_precision_score_fold_out                     0.994699       0.985126
# size                                                    107.0          101.0
# mean_average_precision_score_fold_out_mean           0.997257       0.994979
# mean_average_precision_score_fold_out_std            0.001622       0.002182
# mean_average_precision_score_fold_out_ci_lower       0.994296        0.99112
# mean_average_precision_score_fold_out_ci_upper       0.999534       0.998003
# mean_roc_auc_score_fold_out_mean                     0.994987       0.991374
# mean_roc_auc_score_fold_out_std                      0.003035       0.003352
# mean_roc_auc_score_fold_out_ci_lower                 0.989565       0.985755
# mean_roc_auc_score_fold_out_ci_upper                 0.999242       0.996206
#
#                                                                     295  \
# variable
# target                                          Resistant HTN Heuristic
# model                                                       gpt-4o-iter
# prompt_richness                                                   False
# icd_only                                                          False
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  E
# random_state                                                      16695
# average_precision_score_fold_out                               0.828473
# size                                                              157.0
# mean_average_precision_score_fold_out_mean                      0.90776
# mean_average_precision_score_fold_out_std                      0.032025
# mean_average_precision_score_fold_out_ci_lower                 0.849183
# mean_average_precision_score_fold_out_ci_upper                 0.955817
# mean_roc_auc_score_fold_out_mean                               0.967252
# mean_roc_auc_score_fold_out_std                                0.010532
# mean_roc_auc_score_fold_out_ci_lower                           0.948844
# mean_roc_auc_score_fold_out_ci_upper                           0.984297
#
#                                                                       151  \
# variable
# target                                          Htn-Hypokalemia Heuristic
# model                                                         gpt-4o-iter
# prompt_richness                                                     False
# icd_only                                                            False
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    A
# random_state                                                         6832
# average_precision_score_fold_out                                 0.805917
# size                                                                193.0
# mean_average_precision_score_fold_out_mean                        0.86408
# mean_average_precision_score_fold_out_std                        0.027758
# mean_average_precision_score_fold_out_ci_lower                   0.815298
# mean_average_precision_score_fold_out_ci_upper                   0.907392
# mean_roc_auc_score_fold_out_mean                                 0.871083
# mean_roc_auc_score_fold_out_std                                   0.02674
# mean_roc_auc_score_fold_out_ci_lower                             0.825517
# mean_roc_auc_score_fold_out_ci_upper                             0.912256
#
#                                                                     234  \
# variable
# target                                          Resistant HTN Diagnosis
# model                                                       gpt-4o-iter
# prompt_richness                                                   False
# icd_only                                                          False
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  D
# random_state                                                      14724
# average_precision_score_fold_out                               0.688854
# size                                                              153.0
# mean_average_precision_score_fold_out_mean                     0.863073
# mean_average_precision_score_fold_out_std                      0.038198
# mean_average_precision_score_fold_out_ci_lower                 0.797907
# mean_average_precision_score_fold_out_ci_upper                 0.919086
# mean_roc_auc_score_fold_out_mean                               0.957416
# mean_roc_auc_score_fold_out_std                                0.011578
# mean_roc_auc_score_fold_out_ci_lower                             0.9373
# mean_roc_auc_score_fold_out_ci_upper                           0.975291
#
#                                                                       107
# variable
# target                                          HTN-Hypokalemia Diagnosis
# model                                                         gpt-4o-iter
# prompt_richness                                                     False
# icd_only                                                            False
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    A
# random_state                                                        24481
# average_precision_score_fold_out                                 0.621716
# size                                                                157.0
# mean_average_precision_score_fold_out_mean                       0.784642
# mean_average_precision_score_fold_out_std                        0.041107
# mean_average_precision_score_fold_out_ci_lower                   0.712599
# mean_average_precision_score_fold_out_ci_upper                   0.848099
# mean_roc_auc_score_fold_out_mean                                 0.917428
# mean_roc_auc_score_fold_out_std                                  0.015548
# mean_roc_auc_score_fold_out_ci_lower                             0.891487
# mean_roc_auc_score_fold_out_ci_upper                             0.942131
# ------------------------------------------------------------------------------------------------------------------------
#
# LaTeX table saved to ../paper_rebuttal/tab_best_model_average_precision_score_fold_out_False_False.tex

# %%
# reminder of filename
# filename = (
#     rdir
#     + "/"
#     + "_".join(
#         [
#             targets[target],
#             name,
#             str(scale),
#             str(few_feature),
#             str(prompt_richness),
#             str(repeat),
#             str(fold),
#             str(random_state),
#         ]
#     )
# )
