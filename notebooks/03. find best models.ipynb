# %% [markdown]
# # Find best models
#
# This notebook will load all models and re-evaluate them on all 5 folds, without re-fit. The best model for each phenotype will be selected for further experiments

# %%
from _load_llm_results import *

import numpy as np
import warnings
import os
import importlib
import sys; sys.path.append('../')
from evaluate_model import read_data
from sklearn.metrics import average_precision_score, roc_auc_score

warnings.filterwarnings("ignore")

# %matplotlib inline

from tqdm import tqdm
from glob import glob

def evaluate_all_folds(metric, cp_function, cp_df, folds=['A', 'B', 'C', 'D', 'E'], bootstrap=False, n_reps=1_000, override_runid=False):
    
    runid = cp_df['RunID']
    if override_runid:
        runid = '101' # enforcing to use the held out dataset
        # print("Overriding RunID, Using runID", runid)
        cp_df['RunID'] = runid
    
    def eval(X, y):
        try:
            prob = np.array(cp_function(X))
        except Exception:
            prob = np.zeros(shape=len(X))
        try:
            if metric in [average_precision_score, roc_auc_score]:
                return metric(y, prob)
            else:
                return metric(y, np.where(prob> 0.5), 1, 0)
        except ValueError:
            return np.nan

    for FOLD in folds:
        X_train, y_train, X_test, y_test = read_data(
            targets_rev[cp_df['target']], FOLD, runid, cp_df['scale'],
            cp_df['icd_only'], data_dir, cp_df['random_state']
        )

        entry = f"{metric.__name__}_fold_out_{FOLD}"
        if bootstrap:
            val_samples = []
            for i in tqdm(range(n_reps)):
                samples = np.random.randint(0,len(y_test)-1, size=len(y_test))
                val_samples.append( eval(X_test.iloc[samples, :], y_test.iloc[samples]) )

            cp_df[f"{entry}_mean"] = np.mean(val_samples)
            cp_df[f"{entry}_std"] = np.std(val_samples)
            cp_df[f"{entry}_ci_upper"] = np.quantile(val_samples,0.95)
            cp_df[f"{entry}_ci_lower"] = np.quantile(val_samples,0.05)
        else:
            cp_df[entry] = eval(X_test, y_test)

    return cp_df

def load_results(constraints=dict(scale=[False])):
    count = 0
    for file in tqdm(glob(f"{results_path}/**/*.json", recursive=True)):
        
        try:
            cp_df = pd.read_json(file, typ="series")
        except Exception as e:
            # print("Bad results in file", file)
            continue
            
        # unifying column name
        cp_df = cp_df.rename(index={"few_feature": "icd_only"})
            
        stay = True
        for kc, vc in constraints.items():
            if cp_df[kc] not in vc:
                stay = False
                # print("skipping", file)
                break
        if not stay:
            # print('continuing')
            continue

        # Evaluating the program in the other folds
        cp_file = file.replace('.json', '_program') \
                      .replace(cp_df['target'], targets_rev[cp_df['target']]) \
                      .replace('/', '.')[3:]

        if 'iterative' not in file: # removing the fold from file name if not iterative
            cp_file = cp_file.replace(f"_{cp_df['fold']}_", '__')

        # print(cp_file)

        try:
            cp_module = importlib.__import__(
                cp_file,
                globals(),
                locals(),
                ["predict_hyptertension"],
            )
            cp_function = cp_module.predict_hypertension

            # Evaluating on other held-out folds. notice that the LLMs did not see the
            # entire training data even during its training!
            cp_df = evaluate_all_folds(average_precision_score, cp_function, cp_df)
        except:
            continue

        results.append(cp_df)
        count += 1

    print('loaded',count,'files')
    results_df = pd.DataFrame(data=results)\

    # Beautifying it
    results_df["model"] = results_df["model"].apply(lambda m: nice_model_labels[m])
    results_df["target"] = results_df["target"].apply(lambda t: dnames_to_nice[t])

    results_df = results_df[results_df["model"].isin(order)]

    print(results_df["model"].unique())
    print(results_df["target"].unique())
    
    return results_df
    
results_df = pd.concat([
    load_results( # rich prompt, expert features
        constraints = {
            'scale': [False],
            'model': ['GPT_4o_iterative_Classifier'], 
            'prompt_richness' : [True],
            'icd_only' : [True],
        }
    ),
    load_results( # simple prompt, all features
        constraints = {
            'scale': [False],
            'model': ['GPT_4o_iterative_Classifier'], 
            'prompt_richness' : [False],
            'icd_only' : [False],
        }
    )
])

# Making it the format seaborn likes
results_df_melted = pd.melt(
    results_df, 
    id_vars=['model', 'target', 'fold', 'RunID', 'random_state', 'prompt_richness', 'icd_only', 'scale']
)

print(results_df.columns)
print(results_df.shape)
# Out:
# 100%|██████████| 7199/7199 [04:10<00:00, 28.73it/s]
# loaded 300 files
# ['gpt-4o-iter']
# ['HTN Heuristic' 'HTN Diagnosis' 'HTN-Hypokalemia Diagnosis'
#  'Htn-Hypokalemia Heuristic' 'Resistant HTN Heuristic'
#  'Resistant HTN Diagnosis']
# 100%|██████████| 7199/7199 [15:05<00:00,  7.95it/s]
# loaded 300 files
# ['gpt-4o-iter']
# ['HTN Heuristic' 'HTN Diagnosis' 'HTN-Hypokalemia Diagnosis'
#  'Htn-Hypokalemia Heuristic' 'Resistant HTN Heuristic'
#  'Resistant HTN Diagnosis']
# Index(['accuracy_score_train', 'precision_score_train',
#        'average_precision_score_train', 'roc_auc_score_train',
#        'balanced_accuracy_score_train', 'accuracy_score_test',
#        'precision_score_test', 'average_precision_score_test',
#        'roc_auc_score_test', 'balanced_accuracy_score_test', 'messages',
#        'model', 'target', 'fold', 'RunID', 'random_state', 'representation',
#        'representation_fmt', 'size', 'complexity', 'scale', 'icd_only',
#        'prompt_richness', 'time', 'pred', 'pred_proba',
#        'average_precision_score_fold_out_A',
#        'average_precision_score_fold_out_B',
#        'average_precision_score_fold_out_C',
#        'average_precision_score_fold_out_D',
#        'average_precision_score_fold_out_E'],
#       dtype='object')
# (2100, 31)

# %%
print(results_df_melted.variable.unique())
display(results_df_melted.sample(5))
# Out:
# ['accuracy_score_train' 'precision_score_train'
#  'average_precision_score_train' 'roc_auc_score_train'
#  'balanced_accuracy_score_train' 'accuracy_score_test'
#  'precision_score_test' 'average_precision_score_test'
#  'roc_auc_score_test' 'balanced_accuracy_score_test' 'messages'
#  'representation' 'representation_fmt' 'size' 'complexity' 'time' 'pred'
#  'pred_proba' 'average_precision_score_fold_out_A'
#  'average_precision_score_fold_out_B' 'average_precision_score_fold_out_C'
#  'average_precision_score_fold_out_D' 'average_precision_score_fold_out_E']
#              model                     target fold  RunID  random_state  \
# 15595  gpt-4o-iter    Resistant HTN Diagnosis    E      1         27690
# 22420  gpt-4o-iter    Resistant HTN Heuristic    C      1          1318
# 40462  gpt-4o-iter    Resistant HTN Diagnosis    B      1         16695
# 17205  gpt-4o-iter  HTN-Hypokalemia Diagnosis    A      1         27690
# 5153   gpt-4o-iter              HTN Diagnosis    A      1         24284
#
#        prompt_richness  icd_only  scale                            variable  \
# 15595             True      True  False        average_precision_score_test
# 22420            False     False  False                            messages
# 40462            False     False  False  average_precision_score_fold_out_B
# 17205            False     False  False                  roc_auc_score_test
# 5153              True      True  False       average_precision_score_train
#
#                                                    value
# 15595                                           0.558355
# 22420  [{'role': 'system', 'content': 'You are an AI ...
# 40462                                           0.426443
# 17205                                           0.589506
# 5153                                            0.969969

# %%
for prompt_richness in [True,False]:
    for icd_only in [True,False]:
        for metric in [
            'average_precision_score_fold_out', 
        ]:
            data = (
                results_df_melted[ ( (results_df_melted['variable'].str.contains(metric))
                                   | (results_df_melted['variable']=='size') )
                                 & (results_df_melted['prompt_richness']==prompt_richness)
                                 & (results_df_melted['icd_only']==icd_only)
                ]
                .dropna()
            )

            if len(data)==0:
                continue

            print("prompt_richness", prompt_richness, "expert_features", icd_only)
                        
            # removing the fold name from the metric
            data['variable'].replace({f'{metric}{fold}' : metric for fold in ['_A', '_B', '_C', '_D', '_E']}, inplace=True)
            data['value'] = data['value'].astype(float)
            data['Strategy'] = ['SEDI / Train' if 'iter' in v or 'gpt' not in v else 'Zero Shot' for v in data['model'].values]

            # first we group each model's performance on the held out data and take the mean.
            # then, we ignore folds and random states to get the final model.
            model_metrics_all_folds = data.groupby([
                'target', 'model', 'prompt_richness', 'icd_only', 'Strategy', 'scale',
                'RunID', 'fold', 'random_state', 'variable']
            )['value'].mean().reset_index()

            model_metrics_all_folds = model_metrics_all_folds.pivot_table(
                index=['target', 'model', 'prompt_richness', 'icd_only', 'Strategy', 'scale',
                       'RunID', 'fold', 'random_state'],
                columns='variable',
                values='value'
            ).reset_index()

            # Sorting by size, in case of ties in metric
            best_models = model_metrics_all_folds\
                .sort_values([metric, 'size'], ascending=[False, True])\
                .drop_duplicates(['target', 'model', 'prompt_richness', 'icd_only', 'Strategy', 'scale'])
                
            display(best_models.T)

            best_models[f'size'] = np.nan
            for metric_f in [average_precision_score, roc_auc_score]:
                best_models[f'mean_{metric_f.__name__}_fold_out_mean'] = np.nan
                best_models[f'mean_{metric_f.__name__}_fold_out_std'] = np.nan
                best_models[f'mean_{metric_f.__name__}_fold_out_ci_lower'] = np.nan
                best_models[f'mean_{metric_f.__name__}_fold_out_ci_upper'] = np.nan
            

            # Evaluating it on the held out test partition -----
            held_out_performances = []
            for i, row in best_models.iterrows():
                # print(row)
                # finding the correct file
                filename = (
                    "/".join([results_path,
                              targets_rev[dnames_to_ugly[row['target']]],
                              nice_to_ugly[row['model']] ])
                    + "/"
                    + "_".join(
                        [
                            dnames_to_ugly[row['target']],
                            nice_to_ugly[row['model']],
                            str(row['scale']),
                            str(row['icd_only']),
                            str(row['prompt_richness']),
                            str(row['RunID']),
                            row['fold'],
                            str(row['random_state']),
                        ]
                    )
                    + '.json'
                )
                # print(filename)
                cp_df = pd.read_json(filename, typ="series")

                cp_df = cp_df.rename(index={"few_feature": "icd_only"})

                # Evaluating the program in the other folds
                cp_file = filename.replace('.json', '_program') \
                            .replace(cp_df['target'], targets_rev[cp_df['target']]) \
                            .replace('/', '.')[3:]

                if 'iterative' not in filename: # removing the fold from file name if not iterative
                    cp_file = cp_file.replace(f"_{cp_df['fold']}_", '__')

                # print(cp_file)

                cp_function = None
                try:
                    cp_module = importlib.__import__(
                        cp_file, # This is going to be unique for each algorithm
                        globals(),
                        locals(),
                        ["predict_hyptertension"],
                    )
                    cp_function = cp_module.predict_hypertension
                except:
                    continue
                
                cp_df['RunID'] = '101'
                best_models.loc[i, f'size'] = cp_df['size']
                for metric_f in [average_precision_score, roc_auc_score]:
                    cp_df = evaluate_all_folds(metric_f, cp_function, cp_df, ['A'], bootstrap=True, override_runid=True)
                    
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_mean'] = cp_df[f'{metric_f.__name__}_fold_out_A_mean']
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_std'] = cp_df[f'{metric_f.__name__}_fold_out_A_std']
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_ci_upper'] = cp_df[f'{metric_f.__name__}_fold_out_A_ci_upper']
                    best_models.loc[i, f'mean_{metric_f.__name__}_fold_out_ci_lower'] = cp_df[f'{metric_f.__name__}_fold_out_A_ci_lower']
                    
            display(best_models.T)
    
            print("-"*120)

            # Create LaTeX table
            latex_table = best_models.to_latex(
                index=True,
                column_format="lrrr",
                escape=False
            )
            
            # Save LaTeX table to file
            filename = f"{paper_dir}/tab_best_model_{metric}_{prompt_richness}_{icd_only}.tex"
            with open(filename, 'w') as f:
                f.write(latex_table)
            
            print(f"\nLaTeX table saved to {filename}\n")
# Out:
# prompt_richness True expert_features True
#                                                         162            50   \
# variable
# target                            Htn-Hypokalemia Heuristic  HTN Heuristic
# model                                           gpt-4o-iter    gpt-4o-iter
# prompt_richness                                        True           True
# icd_only                                               True           True
# Strategy                                       SEDI / Train   SEDI / Train
# scale                                                 False          False
# RunID                                                     1              1
# fold                                                      B              A
# random_state                                           6933           1318
# average_precision_score_fold_out                        1.0       0.975953
# size                                                   72.0          237.0
#
#                                             39                         139  \
# variable
# target                            HTN Diagnosis  HTN-Hypokalemia Diagnosis
# model                               gpt-4o-iter                gpt-4o-iter
# prompt_richness                            True                       True
# icd_only                                   True                       True
# Strategy                           SEDI / Train               SEDI / Train
# scale                                     False                      False
# RunID                                         1                          1
# fold                                          D                          D
# random_state                              31658                      31658
# average_precision_score_fold_out       0.968615                   0.815388
# size                                      219.0                      188.0
#
#                                                       260  \
# variable
# target                            Resistant HTN Heuristic
# model                                         gpt-4o-iter
# prompt_richness                                      True
# icd_only                                             True
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    B
# random_state                                         1318
# average_precision_score_fold_out                 0.796539
# size                                                174.0
#
#                                                       200
# variable
# target                            Resistant HTN Diagnosis
# model                                         gpt-4o-iter
# prompt_richness                                      True
# icd_only                                             True
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    A
# random_state                                         1318
# average_precision_score_fold_out                 0.656112
# size                                                188.0
# 100%|██████████| 1000/1000 [00:05<00:00, 174.41it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 319.92it/s]
# 100%|██████████| 1000/1000 [01:44<00:00,  9.56it/s]
# 100%|██████████| 1000/1000 [01:23<00:00, 11.96it/s]
# 100%|██████████| 1000/1000 [01:18<00:00, 12.67it/s]
# 100%|██████████| 1000/1000 [02:12<00:00,  7.56it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 409.13it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 316.24it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 84.41it/s]
# 100%|██████████| 1000/1000 [00:21<00:00, 46.36it/s]
# 100%|██████████| 1000/1000 [00:17<00:00, 58.23it/s]
# 100%|██████████| 1000/1000 [00:11<00:00, 90.32it/s]
#                                                                       162  \
# variable
# target                                          Htn-Hypokalemia Heuristic
# model                                                         gpt-4o-iter
# prompt_richness                                                      True
# icd_only                                                             True
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    B
# random_state                                                         6933
# average_precision_score_fold_out                                      1.0
# size                                                                 72.0
# mean_average_precision_score_fold_out_mean                       0.978095
# mean_average_precision_score_fold_out_std                        0.012587
# mean_average_precision_score_fold_out_ci_lower                   0.956146
# mean_average_precision_score_fold_out_ci_upper                   0.993534
# mean_roc_auc_score_fold_out_mean                                 0.984454
# mean_roc_auc_score_fold_out_std                                  0.008721
# mean_roc_auc_score_fold_out_ci_lower                             0.968734
# mean_roc_auc_score_fold_out_ci_upper                             0.995285
#
#                                                           50             39   \
# variable
# target                                          HTN Heuristic  HTN Diagnosis
# model                                             gpt-4o-iter    gpt-4o-iter
# prompt_richness                                          True           True
# icd_only                                                 True           True
# Strategy                                         SEDI / Train   SEDI / Train
# scale                                                   False          False
# RunID                                                       1              1
# fold                                                        A              D
# random_state                                             1318          31658
# average_precision_score_fold_out                     0.975953       0.968615
# size                                                    237.0          219.0
# mean_average_precision_score_fold_out_mean           0.980818       0.983851
# mean_average_precision_score_fold_out_std            0.009494       0.007686
# mean_average_precision_score_fold_out_ci_lower       0.962657        0.96971
# mean_average_precision_score_fold_out_ci_upper       0.993681       0.994088
# mean_roc_auc_score_fold_out_mean                     0.977073       0.977019
# mean_roc_auc_score_fold_out_std                      0.008326       0.008145
# mean_roc_auc_score_fold_out_ci_lower                 0.962282       0.963391
# mean_roc_auc_score_fold_out_ci_upper                 0.988965       0.989734
#
#                                                                       139  \
# variable
# target                                          HTN-Hypokalemia Diagnosis
# model                                                         gpt-4o-iter
# prompt_richness                                                      True
# icd_only                                                             True
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    D
# random_state                                                        31658
# average_precision_score_fold_out                                 0.815388
# size                                                                188.0
# mean_average_precision_score_fold_out_mean                       0.923449
# mean_average_precision_score_fold_out_std                        0.027173
# mean_average_precision_score_fold_out_ci_lower                   0.874759
# mean_average_precision_score_fold_out_ci_upper                   0.963071
# mean_roc_auc_score_fold_out_mean                                 0.981153
# mean_roc_auc_score_fold_out_std                                    0.0059
# mean_roc_auc_score_fold_out_ci_lower                             0.971184
# mean_roc_auc_score_fold_out_ci_upper                              0.99001
#
#                                                                     260  \
# variable
# target                                          Resistant HTN Heuristic
# model                                                       gpt-4o-iter
# prompt_richness                                                    True
# icd_only                                                           True
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  B
# random_state                                                       1318
# average_precision_score_fold_out                               0.796539
# size                                                              174.0
# mean_average_precision_score_fold_out_mean                     0.831667
# mean_average_precision_score_fold_out_std                      0.040478
# mean_average_precision_score_fold_out_ci_lower                 0.759427
# mean_average_precision_score_fold_out_ci_upper                 0.895183
# mean_roc_auc_score_fold_out_mean                               0.945731
# mean_roc_auc_score_fold_out_std                                0.013718
# mean_roc_auc_score_fold_out_ci_lower                           0.922034
# mean_roc_auc_score_fold_out_ci_upper                            0.96614
#
#                                                                     200
# variable
# target                                          Resistant HTN Diagnosis
# model                                                       gpt-4o-iter
# prompt_richness                                                    True
# icd_only                                                           True
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  A
# random_state                                                       1318
# average_precision_score_fold_out                               0.656112
# size                                                              188.0
# mean_average_precision_score_fold_out_mean                     0.699629
# mean_average_precision_score_fold_out_std                      0.056179
# mean_average_precision_score_fold_out_ci_lower                  0.60313
# mean_average_precision_score_fold_out_ci_upper                 0.788288
# mean_roc_auc_score_fold_out_mean                               0.901499
# mean_roc_auc_score_fold_out_std                                0.018282
# mean_roc_auc_score_fold_out_ci_lower                           0.870173
# mean_roc_auc_score_fold_out_ci_upper                           0.930057
# ------------------------------------------------------------------------------------------------------------------------
#
# LaTeX table saved to ../paper/tab_best_model_average_precision_score_fold_out_True_True.tex
#
# prompt_richness False expert_features False
#                                             66             21   \
# variable
# target                            HTN Heuristic  HTN Diagnosis
# model                               gpt-4o-iter    gpt-4o-iter
# prompt_richness                           False          False
# icd_only                                  False          False
# Strategy                           SEDI / Train   SEDI / Train
# scale                                     False          False
# RunID                                         1              1
# fold                                          B              C
# random_state                              24284           6832
# average_precision_score_fold_out       0.994699       0.985126
# size                                      107.0          101.0
#
#                                                       294  \
# variable
# target                            Resistant HTN Heuristic
# model                                         gpt-4o-iter
# prompt_richness                                     False
# icd_only                                            False
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    E
# random_state                                        14724
# average_precision_score_fold_out                 0.823494
# size                                                250.0
#
#                                                         151  \
# variable
# target                            Htn-Hypokalemia Heuristic
# model                                           gpt-4o-iter
# prompt_richness                                       False
# icd_only                                              False
# Strategy                                       SEDI / Train
# scale                                                 False
# RunID                                                     1
# fold                                                      A
# random_state                                           6832
# average_precision_score_fold_out                   0.805917
# size                                                  193.0
#
#                                                       224  \
# variable
# target                            Resistant HTN Diagnosis
# model                                         gpt-4o-iter
# prompt_richness                                     False
# icd_only                                            False
# Strategy                                     SEDI / Train
# scale                                               False
# RunID                                                   1
# fold                                                    C
# random_state                                        14724
# average_precision_score_fold_out                 0.702629
# size                                                152.0
#
#                                                         107
# variable
# target                            HTN-Hypokalemia Diagnosis
# model                                           gpt-4o-iter
# prompt_richness                                       False
# icd_only                                              False
# Strategy                                       SEDI / Train
# scale                                                 False
# RunID                                                     1
# fold                                                      A
# random_state                                          24481
# average_precision_score_fold_out                   0.621716
# size                                                  157.0
# 100%|██████████| 1000/1000 [00:03<00:00, 298.84it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 364.39it/s]
# 100%|██████████| 1000/1000 [00:07<00:00, 132.21it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 307.74it/s]
# 100%|██████████| 1000/1000 [00:09<00:00, 106.75it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 167.78it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 236.40it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 189.19it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 291.97it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 221.84it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 289.26it/s]
# 100%|██████████| 1000/1000 [00:04<00:00, 237.38it/s]
#                                                           66             21   \
# variable
# target                                          HTN Heuristic  HTN Diagnosis
# model                                             gpt-4o-iter    gpt-4o-iter
# prompt_richness                                         False          False
# icd_only                                                False          False
# Strategy                                         SEDI / Train   SEDI / Train
# scale                                                   False          False
# RunID                                                       1              1
# fold                                                        B              C
# random_state                                            24284           6832
# average_precision_score_fold_out                     0.994699       0.985126
# size                                                    107.0          101.0
# mean_average_precision_score_fold_out_mean           0.997226       0.995108
# mean_average_precision_score_fold_out_std            0.001751       0.001938
# mean_average_precision_score_fold_out_ci_lower       0.993906       0.991617
# mean_average_precision_score_fold_out_ci_upper       0.999631       0.997933
# mean_roc_auc_score_fold_out_mean                       0.9949         0.9915
# mean_roc_auc_score_fold_out_std                      0.003088       0.003346
# mean_roc_auc_score_fold_out_ci_lower                   0.9895       0.985376
# mean_roc_auc_score_fold_out_ci_upper                 0.999313       0.996217
#
#                                                                     294  \
# variable
# target                                          Resistant HTN Heuristic
# model                                                       gpt-4o-iter
# prompt_richness                                                   False
# icd_only                                                          False
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  E
# random_state                                                      14724
# average_precision_score_fold_out                               0.823494
# size                                                              250.0
# mean_average_precision_score_fold_out_mean                     0.875738
# mean_average_precision_score_fold_out_std                      0.030948
# mean_average_precision_score_fold_out_ci_lower                 0.818321
# mean_average_precision_score_fold_out_ci_upper                 0.922306
# mean_roc_auc_score_fold_out_mean                               0.946274
# mean_roc_auc_score_fold_out_std                                0.012015
# mean_roc_auc_score_fold_out_ci_lower                           0.926268
# mean_roc_auc_score_fold_out_ci_upper                           0.965129
#
#                                                                       151  \
# variable
# target                                          Htn-Hypokalemia Heuristic
# model                                                         gpt-4o-iter
# prompt_richness                                                     False
# icd_only                                                            False
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    A
# random_state                                                         6832
# average_precision_score_fold_out                                 0.805917
# size                                                                193.0
# mean_average_precision_score_fold_out_mean                        0.86399
# mean_average_precision_score_fold_out_std                        0.028802
# mean_average_precision_score_fold_out_ci_lower                   0.814388
# mean_average_precision_score_fold_out_ci_upper                   0.909752
# mean_roc_auc_score_fold_out_mean                                 0.872035
# mean_roc_auc_score_fold_out_std                                  0.028449
# mean_roc_auc_score_fold_out_ci_lower                             0.823452
# mean_roc_auc_score_fold_out_ci_upper                             0.917059
#
#                                                                     224  \
# variable
# target                                          Resistant HTN Diagnosis
# model                                                       gpt-4o-iter
# prompt_richness                                                   False
# icd_only                                                          False
# Strategy                                                   SEDI / Train
# scale                                                             False
# RunID                                                                 1
# fold                                                                  C
# random_state                                                      14724
# average_precision_score_fold_out                               0.702629
# size                                                              152.0
# mean_average_precision_score_fold_out_mean                     0.878899
# mean_average_precision_score_fold_out_std                      0.034965
# mean_average_precision_score_fold_out_ci_lower                 0.814183
# mean_average_precision_score_fold_out_ci_upper                 0.928318
# mean_roc_auc_score_fold_out_mean                               0.961687
# mean_roc_auc_score_fold_out_std                                0.010199
# mean_roc_auc_score_fold_out_ci_lower                           0.944079
# mean_roc_auc_score_fold_out_ci_upper                           0.977823
#
#                                                                       107
# variable
# target                                          HTN-Hypokalemia Diagnosis
# model                                                         gpt-4o-iter
# prompt_richness                                                     False
# icd_only                                                            False
# Strategy                                                     SEDI / Train
# scale                                                               False
# RunID                                                                   1
# fold                                                                    A
# random_state                                                        24481
# average_precision_score_fold_out                                 0.621716
# size                                                                157.0
# mean_average_precision_score_fold_out_mean                       0.788384
# mean_average_precision_score_fold_out_std                        0.039549
# mean_average_precision_score_fold_out_ci_lower                   0.723515
# mean_average_precision_score_fold_out_ci_upper                    0.84983
# mean_roc_auc_score_fold_out_mean                                 0.919051
# mean_roc_auc_score_fold_out_std                                  0.015706
# mean_roc_auc_score_fold_out_ci_lower                             0.892243
# mean_roc_auc_score_fold_out_ci_upper                             0.942995
# ------------------------------------------------------------------------------------------------------------------------
#
# LaTeX table saved to ../paper/tab_best_model_average_precision_score_fold_out_False_False.tex

# %%
# reminder of filename
# filename = (
#     rdir
#     + "/"
#     + "_".join(
#         [
#             targets[target],
#             name,
#             str(scale),
#             str(few_feature),
#             str(prompt_richness),
#             str(repeat),
#             str(fold),
#             str(random_state),
#         ]
#     )
# )
